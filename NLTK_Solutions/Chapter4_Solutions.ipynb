# %% [markdown]
# ## 11
# Create a list of words and store it in a variable sent1 . Now assign sent2 = sent1 .
# Modify one of the items in sent1 and verify that sent2 has changed.
# - Now try the same exercise but instead assign sent2 = sent1[:] . Modify sent1
# again and see what happens to sent2 . Explain.
# - Now define text1 to be a list of lists of strings (e.g. to represent a text consisting of
# multiple sentences. Now assign text2 = text1[:] , assign a new value to one of the
# words, e.g. text1[1][1] = 'Monty' . Check what this did to text2 . Explain.
# - Load Python's deepcopy() function (i.e. from copy import deepcopy ), consult its
# documentation, and test that it makes a fresh copy of any object.

# %%
sent1 = list('abcde')
sent2 = sent1
print(sent2)
sent1[0] = 'aa'
print(sent2)
# Out:
# ['a', 'b', 'c', 'd', 'e']
# ['aa', 'b', 'c', 'd', 'e']

# %%
sent1 = list('abcde')
sent2 = sent1[:]
print(sent2)
sent1[0] = 'aa'
print(sent2)
# Out:
# ['a', 'b', 'c', 'd', 'e']
# ['a', 'b', 'c', 'd', 'e']

# %%
text1 = [list('abcde'), list('fghij')]
text2 = text1[:]
print(text2)
text1[0][0] = 'aa'
print(text2)

text1 = [list('abcde'), list('fghij')]
text2 = [[i for i in text] for text in text1]
print(text2)
text1[0][0] = 'aa'
print(text2)
# Out:
# [['a', 'b', 'c', 'd', 'e'], ['f', 'g', 'h', 'i', 'j']]
# [['aa', 'b', 'c', 'd', 'e'], ['f', 'g', 'h', 'i', 'j']]
# [['a', 'b', 'c', 'd', 'e'], ['f', 'g', 'h', 'i', 'j']]
# [['a', 'b', 'c', 'd', 'e'], ['f', 'g', 'h', 'i', 'j']]

# %%
from copy import deepcopy

# %% [markdown]
# ## 12
# Initialize an n-by-m list of lists of empty strings using list multiplication, e.g. word_table
# = [[''] * n] * m . What happens when you set one of its values, e.g. word_table[1][2]
# = "hello" ? Explain why this happens. Now write an expression using range() to construct
# a list of lists, and show that it does not have this problem.

# %%
word_table = [[''] * 2] * 3
print(word_table)
# Out:
# [['', ''], ['', ''], ['', '']]

# %%
word_table[0][1] = 'hello'

# %%
word_table
# Out:
# [['', 'hello'], ['', 'hello'], ['', 'hello']]

# %%
word_table = [["" for _ in range(2)] for _ in range(3)]

# %%
print(word_table)
# Out:
# [['', ''], ['', ''], ['', '']]

# %%
word_table[0][1] = 'hello'
print(word_table)
# Out:
# [['', 'hello'], ['', ''], ['', '']]

# %% [markdown]
# ## 13
# Write code to initialize a two-dimensional array of sets called word_vowels and process
# a list of words, adding each word to word_vowels[l][v] where l is the length of the word
# and v is the number of vowels it contains.

# %%
from nltk.corpus import gutenberg
words = gutenberg.words('austen-emma.txt')[:100]

# %%
max_len = max([len(word) for word in words])
max_vowel = max(([len([char for char in word if char in 'aeiou']) for word in words]))
print(max_len, max_vowel)
# Out:
# 12 6

# %% [markdown]
# ## 14
# Write a function novel10(text) that prints any word that appeared in the last 10% of a
# text that had not been encountered earlier.

# %%
def novel10(text):
    first = text[:int(len(text)*0.9)]
    latter = text[int(len(text)*0.9):]
    for word in latter:
        if word not in first:
            print(word)

# %%
from nltk.corpus import gutenberg
words = gutenberg.words('austen-emma.txt')

# %%
novel10(words)
# Out:
# absented
# reprehension
# excites
# dropped
# indicated
# Amiable
# goodhumoured
# expiration
# penetrated
# extenuation
# sinned
# Acquit
# acquittal
# brotherly
# queernesses
# --,
# designedly
# suppress
# insane
# encroach
# unseasonableness
# 26th
# ult
# shrunk
# retrospect
# shamefully
# blameable
# disapproved
# dissatisfaction
# consistent
# objectionable
# particularity
# consenting
# useless
# officious
# filled
# hatred
# extended
# bandied
# _felt_
# _engagement_
# _be_
# _a_
# _source_
# _repentance_
# _and_
# _misery_
# _each_
# _dissolved_
# _it_
# multiplicity
# locked
# stating
# adding
# misconstrued
# subordinate
# conveyance
# requested
# --:
# stared
# accordant
# descriptive
# threaten
# raved
# wan
# release
# dictate
# undoubted
# subscribe
# Son
# WESTON
# CHURCHILL
# foretold
# Bad
# impartial
# distrusted
# disapprobation
# Playing
# Too
# acquittal
# Fancying
# fathomed
# Natural
# intrigue
# Mystery
# Finesse
# pervert
# boyish
# shamefully
# shamefully
# contend
# consenting
# repentance
# dissolved
# suffers
# "`
# Dearer
# thanker
# tens
# Happier
# inconsideration
# thoughtlessness
# acquire
# attacking
# inadmissibility
# transplantation
# objectionable
# Like
# evinced
# sacrificing
# unprovided
# expectant
# saucy
# detecting
# contemplated
# outweigh
# periods
# cheerlessness
# involve
# loser
# worshipped
# _three_
# reproaches
# usage
# bordering
# desirableness
# stroke
# resorting
# tooth
# dentist
# dentist
# haunted
# enduring
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-9b53c5767c07> in <module>
# ----> 1 novel10(words)
#
# <ipython-input-59-f6e29e656c93> in novel10(text)
#       3     latter = text[int(len(text)*0.9):]
#       4     for word in latter:
# ----> 5         if word not in first:
#       6             print(word)
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\collections.py in __contains__(self, value)
#     201     def __contains__(self, value):
#     202         """Return true if this list contains ``value``."""
# --> 203         return bool(self.count(value))
#     204
#     205     def __add__(self, other):
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\collections.py in count(self, value)
#     186     def count(self, value):
#     187         """Return the number of times this list contains ``value``."""
# --> 188         return sum(1 for elt in self if elt == value)
#     189
#     190     def index(self, value, start=None, stop=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\collections.py in <genexpr>(.0)
#     186     def count(self, value):
#     187         """Return the number of times this list contains ``value``."""
# --> 188         return sum(1 for elt in self if elt == value)
#     189
#     190     def index(self, value, start=None, stop=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\corpus\reader\util.py in iterate_from(self, start_tok)
#     304             self._current_toknum = toknum
#     305             self._current_blocknum = block_index
# --> 306             tokens = self.read_block(self._stream)
#     307             assert isinstance(tokens, (tuple, list, AbstractLazySequence)), (
#     308                 'block reader %s() should return list or tuple.'
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\corpus\reader\plaintext.py in _read_word_block(self, stream)
#     132         words = []
#     133         for i in range(20):  # Read 20 lines at a time.
# --> 134             words.extend(self._word_tokenizer.tokenize(stream.readline()))
#     135         return words
#     136
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\data.py in readline(self, size)
#    1217
#    1218         while True:
# -> 1219             startpos = self.stream.tell() - len(self.bytebuffer)
#    1220             new_chars = self._read(readsize)
#    1221
#
# KeyboardInterrupt:

# %% [markdown]
# ## 15
#  Write a program that takes a sentence expressed as a single string, splits it and counts
# up the words. Get it to print out each word and the word's frequency, one per line, in
# alphabetical order.

# %%
import nltk
def freq(text):
    text = text.split()
    fdist = nltk.FreqDist(text)
    for word in sorted(fdist.keys()):
        print(word, fdist[word])

# %%
from nltk.corpus import gutenberg
text = gutenberg.raw('austen-emma.txt')[:10000]

# %%
freq(text)
# Out:
# "A 1
# "But 1
# "How 1
# "I 2
# "It 1
# "My 1
# "No, 1
# "Not 1
# "Poor 1
# "The 1
# "They 1
# "poor 1
# (and 1
# 1816] 1
# A 1
# All 1
# And 1
# Austen 1
# Between 1
# Brunswick 1
# But 1
# CHAPTER 1
# Christmas 1
# Emma 7
# Emma's 1
# Emma. 1
# Even 1
# Hannah 2
# Hartfield 1
# Hartfield, 2
# Hartfield. 1
# He 5
# Her 3
# Highbury, 2
# His 1
# How 1
# I 16
# Isabella 1
# Isabella" 1
# Isabella's 2
# It 6
# James 3
# James, 1
# Jane 1
# Knightley 1
# Knightley, 2
# London, 1
# London. 1
# Matrimony, 1
# Miss 12
# Mr. 12
# Mrs. 1
# Nobody 1
# November 1
# October 1
# Randalls 1
# Randalls, 1
# She 5
# Sixteen 1
# Sorrow 1
# Square. 1
# Taylor 10
# Taylor!--I 1
# Taylor's 2
# That 1
# The 8
# This 1
# VOLUME 1
# We 2
# Weston 4
# Weston's 1
# Weston, 1
# What 1
# When 1
# Whenever 2
# Woodhouse 3
# Woodhouse's 1
# Woodhouse, 1
# Woodhouses 1
# You 2
# [Emma 1
# _We_ 1
# _them_ 1
# a 50
# able 2
# about 3
# absence, 1
# accepted 1
# account; 1
# acquaintance 1
# activity 1
# actual 1
# advantage 1
# advantages, 1
# affection 2
# affection, 1
# affection. 1
# affectionate, 1
# afforded 1
# afraid 1
# after 3
# afterwards 1
# again. 2
# age, 1
# ages 1
# ago 1
# agree 1
# all 12
# all, 1
# allowed 1
# alloy 1
# almost 1
# already. 1
# always 8
# am 5
# amiable 1
# among 1
# amounting 1
# amuse 1
# an 4
# and 65
# animated 1
# answered 1
# any 7
# anywhere 1
# are 3
# are." 1
# arose, 1
# as 18
# asks 1
# at 9
# attach 1
# attached, 1
# attacked 1
# authority 1
# aware 1
# away, 1
# awoke, 1
# back 1
# backgammon, 1
# backgammon-table 1
# bangs 1
# be 16
# bear 2
# beautiful 1
# because 1
# been 8
# before 2
# begin; 1
# being 5
# belong, 1
# beloved 2
# best 1
# between 1
# beyond 1
# black 1
# blessings 1
# body 1
# body, 1
# both 1
# shocking 1
# short 1
# shrubberies, 1
# sigh 1
# sir. 1
# sister's 1
# sister, 1
# sisters. 1
# sit 1
# situation 1
# sixteen 2
# sleep 1
# slighted 1
# smiled 1
# so 5
# society 1
# solitude. 1
# some 4
# somebody 1
# soon 1
# soon." 1
# sorrow--but 1
# spared 1
# speak 2
# spent 1
# spirits 1
# spite 1
# stable, 1
# struggled 1
# such 6
# suffering 1
# suitable 1
# supplied 1
# support. 1
# suppose 1
# sure 3
# sure." 1
# take 1
# talents 1
# talked 1
# taught 1
# tea 1
# tell 1
# temper 1
# temper, 1
# tenderer 1
# than 4
# that 13
# the 43
# their 4
# them 1
# them, 3
# them. 1
# them; 2
# then 1
# there 1
# there. 2
# these 1
# they 3
# thing 1
# things, 1
# think 5
# third 1
# this 5
# thoroughly 1
# though 3
# thought 5
# thoughts; 1
# threatened 1
# three 1
# through 3
# till 2
# time 1
# time. 2
# times 1
# to 50
# to, 1
# together 1
# together, 1
# tolerably 1
# too 3
# too; 1
# town, 1
# true 1
# turns 1
# twenty-one 1
# two 1
# unexceptionable 1
# unite 1
# universally 1
# unnecessary. 1
# unperceived, 1
# unreserve 1
# up 2
# upon 2
# us 2
# us!--We 1
# us. 2
# used 2
# useful, 1
# usual, 2
# valetudinarian 1
# various 1
# very 14
# vex 1
# village, 1
# visit 2
# visit?" 1
# visitor 1
# visitor, 1
# walk 1
# walk." 1
# walked 2
# walking. 1
# want 1
# was 35
# way 1
# way, 1
# way;--and 1
# ways 2
# we 5
# wedding 2
# wedding-day 1
# welcome 1
# welcome, 1
# well 2
# well-informed, 1
# were 7
# what 3
# when 4
# where 2
# whether 1
# which 5
# while 1
# who 3
# whom 1
# wife;--and 1
# will 8
# wish 2
# wished 1
# with 14
# without 1
# woman 1
# work 1
# world 1
# would 4
# years 3
# years, 1
# years--how 1
# years; 1
# yet 2
# you 9
# you!" 1
# you, 2
# youngest 1
# your 3

# %% [markdown]
# ## 16
# Read up on Gematria, a method for assigning numbers to words, and for mapping
# between words having the same number to discover the hidden meaning of texts
# ( http://en.wikipedia.org/wiki/Gematria , http://essenes.net/gemcal.htm ).
# - Write a function gematria() that sums the numerical values of the letters of a word,
# according to the letter values in letter_vals :
#  > letter_vals = {'a':1, 'b':2, 'c':3, 'd':4, 'e':5, 'f':80, 'g':3, 'h':8,
#  'i':10, 'j':10, 'k':20, 'l':30, 'm':40, 'n':50, 'o':70, 'p':80, 'q':100,
#  'r':200, 's':300, 't':400, 'u':6, 'v':6, 'w':800, 'x':60, 'y':10, 'z':7}
# - Process a corpus (e.g. nltk.corpus.state_union ) and for each document, count
# how many of its words have the number 666.
# - Write a function decode() to process a text, randomly replacing words with their
# Gematria equivalents, in order to discover the "hidden meaning" of the text.

# %% [markdown]
# ## 18
# Write a function shorten(text, n) to process a text, omitting the n most frequently
# occurring words of the text. How readable is it?

# %%
import nltk

# %%
def short(text, n):
    text_lower = [w.lower() for w in text]
    target = [w for w, _ in nltk.FreqDist(text_lower).most_common(n)]
    text = [w for w in text if w.lower() not in target]
    return ' '.join(text)

# %%
words = nltk.corpus.gutenberg.words('austen-emma.txt')
short(words, 20)
# Out:
# '[ Emma by Jane Austen 1816 ] VOLUME CHAPTER Emma Woodhouse handsome clever rich with comfortable home happy disposition seemed unite some best blessings existence had lived nearly twenty - one years world with very little distress or vex youngest two daughters most affectionate indulgent father had consequence sister \' s marriage been mistress his house from very early period mother had died too long ago for have more than an indistinct remembrance caresses place had been supplied by an excellent woman as governess who had fallen little short mother affection Sixteen years had Miss Taylor been Mr Woodhouse \' s family less as governess than friend very fond both daughters but particularly Emma Between _them_ more intimacy sisters Even before Miss Taylor had ceased hold nominal office governess mildness temper had hardly allowed impose any restraint shadow authority being now long passed away they had been living together as friend friend very mutually attached Emma doing just what liked highly esteeming Miss Taylor \' s judgment but directed chiefly by own real evils indeed Emma \' s situation were power having rather too much own way disposition think little too well herself these were disadvantages which threatened alloy many enjoyments danger however at present so unperceived they did by any means rank as misfortunes with Sorrow came -- gentle sorrow -- but at all shape any disagreeable consciousness .-- Miss Taylor married Miss Taylor \' s loss which first brought grief on wedding - day this beloved friend Emma first sat mournful thought any continuance wedding over bride - people gone father herself were left dine together with no prospect third cheer long evening father composed himself sleep after dinner as usual had then only sit think what had lost event had every promise happiness for friend Mr Weston man unexceptionable character easy fortune suitable age pleasant manners there some satisfaction considering with what self - denying generous friendship had always wished promoted match but black morning \' s work for want Miss Taylor would felt every hour every day recalled past kindness -- kindness affection sixteen years -- how had taught how had played with from five years old -- how had devoted all powers attach amuse health -- how nursed through various illnesses childhood large debt gratitude owing here but intercourse last seven years equal footing perfect unreserve which had soon followed Isabella \' s marriage on their being left each other yet dearer tenderer recollection had been friend companion such as few possessed : intelligent well - informed useful gentle knowing all ways family interested all its concerns peculiarly interested herself every pleasure every scheme hers -- one whom could speak every thought as arose who had such an affection for as could never find fault How bear change ?-- true friend going only half mile from them but Emma aware great must difference between Mrs Weston only half mile from them Miss Taylor house with all advantages natural domestic now great danger suffering from intellectual solitude dearly loved father but no companion for could meet conversation rational or playful evil actual disparity their ages ( Mr Woodhouse had married early ) much increased by his constitution habits for having been valetudinarian all his life without activity mind or body much older man ways than years though everywhere beloved for friendliness his heart his amiable temper his talents could have recommended him at any time sister though comparatively but little removed by matrimony being settled London only sixteen miles off much beyond daily reach many long October November evening must struggled through at Hartfield before Christmas brought next visit from Isabella husband their little children fill house give pleasant society again Highbury large populous village almost amounting town which Hartfield spite its separate lawn shrubberies name did really belong afforded no equals Woodhouses ...

# %% [markdown]
# ## 18
# Write code to print out an index for a lexicon, allowing someone to look up words
# according to their meanings (or pronunciations; whatever properties are contained in
# lexical entries).
